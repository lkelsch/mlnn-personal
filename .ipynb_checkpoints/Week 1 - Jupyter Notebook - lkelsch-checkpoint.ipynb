# %%
3+5
# Out:
# 8

# %%
import numpy

# %%
trek = ("Kirk", "Picard", "Data", "Spock", "McCoy")
len(trek)
# Out:
# 5

# %%
print("Welcome to the course!")
# Out:
# Welcome to the course!

# %%
import matplotlib.pyplot as plt

# %%
a = [1,2]
b = [3,4]

plt.plot(a, "g")
plt.plot(b, "r")
